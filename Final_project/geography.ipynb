# %%
from geopy import Nominatim
import numpy as np
import pandas as pd

# %%
address = "Шоми Сахар"
add = str(address)+", Dushanbe, Tajikistan"
locator = Nominatim(user_agent="myGeocoder")
location = locator.geocode(add)

print(location)
print(location.latitude)
print(location.longitude)
# Out:
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /mnt/c/Users/mirzonabot.mirzonabo/Desktop/DS/Data_Science_projects/geography.ipynb Cell 2' in <module>
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/mirzonabot.mirzonabo/Desktop/DS/Data_Science_projects/geography.ipynb#ch0000002vscode-remote?line=3'>4</a> location = locator.geocode(add)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/mirzonabot.mirzonabo/Desktop/DS/Data_Science_projects/geography.ipynb#ch0000002vscode-remote?line=5'>6</a> print(location)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/mirzonabot.mirzonabo/Desktop/DS/Data_Science_projects/geography.ipynb#ch0000002vscode-remote?line=6'>7</a> print(location.latitude)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/mirzonabot.mirzonabo/Desktop/DS/Data_Science_projects/geography.ipynb#ch0000002vscode-remote?line=7'>8</a> print(location.longitude)
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
data = pd.read_csv("estate_data.csv")

data.head()

not_found = []

not_found = [np.nan]
def geoloc(address):
    if pd.isnull(address):
        print(str(address) + " Not found")
        return (np.nan,np.nan)
    if address.split(" ")[0].isnumeric():
        address = address.split(" ")[0].strip()
    if address[-1].isalnum() == False:
        address = address[0:-1]
    if address[0:2] == "н.":
        address = address.split(" ")[0][2:]
    add = str(address)+", Dushanbe, Tajikistan"
    locator = Nominatim(user_agent="myGeocoder")
    location = locator.geocode(add)
    if location == None:
        address = address.split(" ")[0]
        add = str(address)+", Dushanbe, Tajikistan"
        locator = Nominatim(user_agent="myGeocoder")
        location = locator.geocode(add)
    if (location is None) :
        not_found.append(address)
        not_found.append(address)
        print(address + " Not found")
        return (np.nan,np.nan)
    return (location.latitude,location.longitude)

data["latitude, longitude"] = data["address"].apply(geoloc)

print("Latitude and longitude added!")

data.to_csv("estate_data1.csv")

data.head()
# Out:
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Караболо Not found
# Караболо Not found
# nan Not found
# nan Not found
# Зелёный Not found
# Зелёный Not found
# nan Not found
# Сельхозинститут Not found
# Сельхозинститут Not found
# Ориентир Not found
# Шозмансур Not found
# nan Not found
# Караболо Not found
# nan Not found
# Исмойли Not found
# 112мкр Not found
# nan Not found
# nan Not found
# 82мкр Not found
# Испечак2 Not found
# Караболо Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Зеленый Not found
# Зеленый Not found
# поёни Not found
# nan Not found
# nan Not found
# nan Not found
# Cадбарг Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Диагностика Not found
# Фирдаси Not found
# nan Not found
# Караболо Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Зеленый Not found
# Зеленый Not found
# nan Not found
# 112мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# наздикии Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Зеленый Not found
# Мачити Not found
# Зеленый Not found
# Караболо Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 112мкр Not found
# 103мкр Not found
# 112мкр Not found
# nan Not found
# Казинои Not found
# Казинои Not found
# Кольцевой Not found
# 92мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 112мкр Not found
# nan Not found
# 102мкр Not found
# Колхоз Not found
# nan Not found
# Скорая Not found
# nan Not found
# 92мкр Not found
# nan Not found
# nan Not found
# Cино Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 92мкр Not found
# nan Not found
# 92мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Скорая Not found
# Караболо Not found
# Караболо Not found
# nan Not found
# nan Not found
# Караболо Not found
# nan Not found
# nan Not found
# профсаюз Not found
# Cино Not found
# nan Not found
# Сельхоз Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 7км Not found
# 104мкр Not found
# nan Not found
# 102мкр Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# 92мкр Not found
# 92мкр Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Старый Not found
# nan Not found
# nan Not found
# nan Not found
# 102мкр Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# 102мкр Not found
# Путовский- Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# ориентир Not found
# Ориентир Not found
# ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Мачити Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# ориентир Not found
# Поени Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Гравзавод Not found
# Ориентир Not found
# Ориентир Not found
# Поёни Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# 33мкр Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Гипразем Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# 92мкр Not found
# ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# 83мкр Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# nan Not found
# Ориентир Not found
# nan Not found
# nan Not found
# Гипразем Not found
# Скорый Not found
# nan Not found
# Политехнический Not found
# nan Not found
# 112мкр Not found
# nan Not found
# nan Not found
# 112мкр Not found
# nan Not found
# 92мкр Not found
# 102мкр Not found
# nan Not found
# 61мкр Not found
# nan Not found
# Сзади Not found
# nan Not found
# Фирдауси Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 65мкр Not found
# майковски Not found
# 91мкр Not found
# Караболо Not found
# nan Not found
# 112мкр Not found
# Ориентир Not found
# ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# 104мкр Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Минтранса Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ленинский Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Поёни Not found
# ориентир Not found
# ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# 102мкр Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# nan Not found
# ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Казинои Not found
# Казинои Not found
# Зеленый Not found
# 91мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# ДомПечать Not found
# Шарора Not found
# nan Not found
# nan Not found
# 92мкр Not found
# 112мкр Not found
# nan Not found
# nan Not found
# 102мкр Not found
# 92мкр Not found
# Китай Not found
# nan Not found
# Ориентир Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# аэрапорт Not found
# 82-Саодат Not found
# Cино Not found
# Караболо Not found
# 92мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Домпечать Not found
# nan Not found
# nan Not found
# nan Not found
# Бустон Not found
# 82мкр Not found
# nan Not found
# nan Not found
# nan Not found
# 103мкр Not found
# Ориентир Not found
# nan Not found
# nan Not found
# nan Not found
# 92мкр Not found
# Зелёный Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 82мкр Not found
# nan Not found
# Товус Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Хукумат Not found
# nan Not found
# nan Not found
# Шомансур Not found
# nan Not found
# 82мкр Not found
# 92мкр Not found
# nan Not found
# nan Not found
# 46мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Шаҳраки Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Мост Not found
# nan Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Сзади Not found
# nan Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Ориентир Not found
# nan Not found
# Сельхоз Not found
# 112мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Ориентир Not found
# nan Not found
# nan Not found
# Сзади Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# nan Not found
# nan Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Cино Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Гипразем Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Ориентир Not found
# Скорая Not found
# Ориентир Not found
# Центр-Симург Not found
# гипразем Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Караболо Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ателье Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# 102мкр Not found
# Испечак2 Not found
# Ориентир Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 91мкр Not found
# nan Not found
# Караболо Not found
# Водонасосная Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Аэрапорт Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# 102мкр Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# подземка Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Водонасосная Not found
# ориентир Not found
# Водонасосная Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Ориентир Not found
# nan Not found
# ул.Чехова Not found
# nan Not found
# Скорая Not found
# Ориентир Not found
# Cадбарг Not found
# Ориентир Not found
# Ориентир Not found
# Cино Not found
# Ориентир Not found
# nan Not found
# 101мкр Not found
# nan Not found
# nan Not found
# Вефа Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# 33мкр Not found
# 82мкр Not found
# nan Not found
# nan Not found
# nan Not found
# 82мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Кароболо Not found
# nan Not found
# nan Not found
# nan Not found
# Шомансур Not found
# nan Not found
# Сельхозинститут Not found
# 92мкр-н Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Караболо Not found
# Ориентир Not found
# 82мкр Not found
# nan Not found
# 84мкр Not found
# nan Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# nan Not found
# Бобочон Not found
# nan Not found
# nan Not found
# nan Not found
# 112-мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 91мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Китай Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 102мкр Not found
# 103мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 1-советский Not found
# КохиБорбад Not found
# Скорый Not found
# nan Not found
# nan Not found
# Ориентир Not found
# Шомансур Not found
# 102мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Кожзавод Not found
# nan Not found
# 112мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Колхоз Not found
# Cино Not found
# nan Not found
# 63мкр Not found
# Ориентир Not found
# nan Not found
# Хукумат Not found
# nan Not found
# nan Not found
# 33-мкр Not found
# nan Not found
# nan Not found
# Ботанический Not found
# Чулочная Not found
# Пединститут Not found
# Караболо Not found
# Ориентир Not found
# Сельхозинститут Not found
# nan Not found
# nan Not found
# Карабало Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Поени Not found
# Док Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 103мкр Not found
# 61мкр Not found
# Сомонй Not found
# nan Not found
# 104мкр Not found
# nan Not found
# nan Not found
# 63мкр Not found
# 32мкр Not found
# nan Not found
# 103мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Водонасосная Not found
# 102мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 82мкр-н Not found
# nan Not found
# Cино Not found
# nan Not found
# nan Not found
# nan Not found
# 46мкр Not found
# nan Not found
# nan Not found
# nan Not found
# Зелёный Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Сзади Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 112мкр Not found
# Автоцентр Not found
# nan Not found
# nan Not found
# nan Not found
# Поени Not found
# 92мкр Not found
# nan Not found
# nan Not found
# nan Not found
# 91мкр Not found
# 102мкр Not found
# 103мкр Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# ориентир Not found
# Ориентир Not found
# nan Not found
# nan Not found
# 84мкр Not found
# 84мкр Not found
# nan Not found
# nan Not found
# Диагностика Not found
# 32мкр Not found
# 82мкр Not found
# nan Not found
# nan Not found
# Кукольный Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Караболо Not found
# nan Not found
# nan Not found
# nan Not found
# 112мкр Not found
# 61мкр Not found
# Караболо Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 91мкр Not found
# Караболо Not found
# 46мкр Not found
# Ориентир Not found
# nan Not found
# 65мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# И.Сомоний Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# nan Not found
# Водонасосная Not found
# nan Not found
# 65мкр Not found
# nan Not found
# nan Not found
# 112мкр Not found
# Водонасосная Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 84мкр Not found
# nan Not found
# Доми Not found
# nan Not found
# nan Not found
# nan Not found
# 91мкр Not found
# nan Not found
# Ориентир Not found
# Пединиститут Not found
# nan Not found
# Перекрёсток Not found
# nan Not found
# 92мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Скорая Not found
# Пединститут Not found
# 112мкр Not found
# nan Not found
# Диагностика Not found
# Караболо Not found
# Филармонияы Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Прафсаюз Not found
# Пединститут Not found
# 102мкр-н Not found
# Скорая Not found
# 33мкр-н Not found
# 91мкр Not found
# 103мкр Not found
# Караболо Not found
# nan Not found
# nan Not found
# Сельхозинститут Not found
# nan Not found
# nan Not found
# Скорая Not found
# 112мкр-н Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Ориентир Not found
# nan Not found
# Вефа Not found
# Сзади Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 102мкр Not found
# Китай Not found
# Заравшон Not found
# nan Not found
# МЖК Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Гравзавод Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Кукольный Not found
# 101мкр Not found
# Ориентир Not found
# Площадь Not found
# nan Not found
# nan Not found
# 92мкр Not found
# 112мкр Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Диагностика Not found
# Ориентир Not found
# Караболо Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# 102мкр Not found
# nan Not found
# Караболо Not found
# nan Not found
# nan Not found
# nan Not found
# 104мкр Not found
# nan Not found
# Мост Not found
# Повороти Not found
# nan Not found
# nan Not found
# nan Not found
# 91мкр Not found
# nan Not found
# nan Not found
# 103мкр Not found
# 91мкр Not found
# 92мкр Not found
# nan Not found
# Перекрёсток Not found
# nan Not found
# nan Not found
# Колхоз Not found
# nan Not found
# nan Not found
# nan Not found
# Нохияй Not found
# nan Not found
# nan Not found
# 92мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Хитойбозор Not found
# Диагностика Not found
# Пости Not found
# Пединститут Not found
# nan Not found
# Ориентир Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Шахраки Not found
# 92мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Напротив Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Колхоз Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# nan Not found
# 18мкр Not found
# nan Not found
# Ориентир Not found
# nan Not found
# 103мкр Not found
# nan Not found
# nan Not found
# МЖК Not found
# 101мкр Not found
# nan Not found
# nan Not found
# 104мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 46мкр Not found
# nan Not found
# nan Not found
# nan Not found
# Караболо Not found
# Сельхоз Not found
# nan Not found
# Диагностика Not found
# nan Not found
# nan Not found
# Зарафшон-зарнисор Not found
# nan Not found
# nan Not found
# Док. Not found
# nan Not found
# nan Not found
# 82мкр Not found
# nan Not found
# 33мкр Not found
# nan Not found
# nan Not found
# Ахрора Not found
# 82мкр Not found
# nan Not found
# Cино Not found
# 91мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 92мкр Not found
# nan Not found
# nan Not found
# nan Not found
# напротив Not found
# nan Not found
# Сельхоз Not found
# Сзади Not found
# nan Not found
# nan Not found
# nan Not found
# 92мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Караболо Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 65мкр Not found
# nan Not found
# скорая Not found
# nan Not found
# nan Not found
# Файзобод Not found
# nan Not found
# nan Not found
# Гипразем Not found
# 112мкр Not found
# 112мкр Not found
# Cино Not found
# 102мкр Not found
# nan Not found
# Қараболо Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 92мкр Not found
# nan Not found
# nan Not found
# 82-мкр Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# nan Not found
# Караболо Not found
# nan Not found
# МЖК Not found
# Азия Not found
# 91мкр Not found
# Ориентир Not found
# Ориентир Not found
# ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# 92мкр Not found
# Ориентир Not found
# nan Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# напротив Not found
# nan Not found
# Караболо Not found
# nan Not found
# nan Not found
# Диагностика Not found
# Профсаюз Not found
# nan Not found
# Караболо Not found
# Пединститут Not found
# nan Not found
# Караболо Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Караболо Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Шарора Not found
# Ориентир Not found
# Cино Not found
# nan Not found
# Cино Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Cино Not found
# Шомансур Not found
# nan Not found
# nan Not found
# nan Not found
# Караболо Not found
# Караболо Not found
# nan Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Заравшон Not found
# Пайкари Not found
# nan Not found
# nan Not found
# nan Not found
# Зеленый Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Гипразем Not found
# Маяковкий Not found
# Диагностика Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# nan Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# 92мкр Not found
# nan Not found
# Ориентир Not found
# 32мкр Not found
# nan Not found
# nan Not found
# Tанк Not found
# А.Каххоров Not found
# nan Not found
# nan Not found
# Фирдавсй Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Тоҷирон Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Караболо Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# МЖК Not found
# НалоговойШохмансура Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# 33мкр Not found
# nan Not found
# Перекрёсток Not found
# Ориентир Not found
# ДетскогоЦентраМадагаскар Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Водонасосная Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Автоцентр Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# МЖК Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Перекрёсток Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# nan Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Cино Not found
# nan Not found
# nan Not found
# Сельхозинститут Not found
# nan Not found
# 112мкр Not found
# 46мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Мост Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# nan Not found
# nan Not found
# 104мкр Not found
# nan Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# ориентир Not found
# Ориентир Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 46мкр Not found
# ул.Зарафшон Not found
# 112мкр Not found
# 101-мкр Not found
# Глазная Not found
# Старый Not found
# nan Not found
# nan Not found
# nan Not found
# 105мкр Not found
# 91мкр Not found
# 101мкр Not found
# 82мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# 92мкр Not found
# 33мкр-н Not found
# nan Not found
# Гулбута Not found
# Хитойбозор Not found
# nan Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# ЗАРАФШОН-ЁВАР Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Колхоз Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# 91мкр Not found
# Ориентир Not found
# Ориентир Not found
# 33мкр Not found
# Ориентир Not found
# Площадь Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# nan Not found
# Хитойбозор Not found
# Сирк Not found
# Pудаки Not found
# nan Not found
# Караболо Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Зеленый Not found
# Славянскогоинститута Not found
# nan Not found
# Скорая Not found
# Cино Not found
# nan Not found
# nan Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# 102мкр Not found
# Хитойбозор Not found
# Товус Not found
# Ориентир Not found
# Ориентир Not found
# магазинаЛасточка Not found
# Ориентир Not found
# Поёни Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# nan Not found
# Караболо Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Южный Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# ориентир Not found
# магазинаЛасточка Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# nan Not found
# nan Not found
# nan Not found
# Ориентир Not found
# 64мкр Not found
# nan Not found
# nan Not found
# nan Not found
# ориентир Not found
# Р-он Not found
# Ориентир Not found
# Ориентир Not found
# 112мкр Not found
# 91мкр Not found
# nan Not found
# 103мкр Not found
# 101мкр Not found
# nan Not found
# nan Not found
# 61мкр Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# 84мкр Not found
# Ориентир Not found
# 102мкр Not found
# 82мкр Not found
# nan Not found
# nan Not found
# 92мкр Not found
# nan Not found
# nan Not found
# Жилмасив Not found
# nan Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# nan Not found
# 92мкр Not found
# Ориентир Not found
# 92мкр Not found
# Ориентир Not found
# nan Not found
# nan Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# ориентир Not found
# 102мкр Not found
# nan Not found
# Филармония(кольцовой Not found
# Караболо Not found
# nan Not found
# nan Not found
# nan Not found
# Ориентир Not found
# nan Not found
# Поёни Not found
# nan Not found
# Ориентир Not found
# nan Not found
# nan Not found
# nan Not found
# 102мкр Not found
# Доми Not found
# nan Not found
# Шомансур Not found
# nan Not found
# nan Not found
# nan Not found
# Хитойбозор Not found
# nan Not found
# nan Not found
# 103мкр Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Миноборона Not found
# Чино Not found
# 33мкр Not found
# Колхоз Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# ориентир Not found
# nan Not found
# nan Not found
# nan Not found
# Немецкая Not found
# nan Not found
# Фирдаси Not found
# nan Not found
# nan Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# 64мкр Not found
# Ориентир Not found
# Ботанический Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# nan Not found
# 84мкр Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# 33мкр Not found
# nan Not found
# nan Not found
# Ориентир Not found
# nan Not found
# nan Not found
# nan Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Шарора Not found
# Водонасосная Not found
# Гулдаста-82мкр Not found
# nan Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# nan Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# Ориентир Not found
# ориентир Not found
# Ориентир Not found
# Latitude and longitude added!
#    number_of_rooms  floor  area        address           date   price  \
# 0                1      1  58.0         Сомони  Сегодня 21:56  330000
# 1                1     14  68.0         92 мкр  Сегодня 21:56  340000
# 2                3      8  50.0            NaN  Сегодня 21:55  700000
# 3                3     14  84.0        112 мкр  Сегодня 21:51  700000
# 4                3      3  83.0  фабрика Ширин  Сегодня 21:48  415000
#
#                        latitude, longitude
# 0                  (38.5858337, 68.793715)
# 1         (38.52225355, 68.74991793788521)
# 2                               (nan, nan)
# 3                (38.5208346, 68.74790775)
# 4  (38.564374400000005, 68.73941921022708)

# %%
# new_data = data[0:10]
# new_data["latitude,longitude"] = new_data["address"].apply(geoloc)
# Out:
# nan Not found
# nan Not found
# nan Not found
# /tmp/ipykernel_1941/92356258.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["latitude,longitude"] = new_data["address"].apply(geoloc)

# %%
new_data.head()
# Out:
#    number_of_rooms  floor  area        address           date   price  \
# 0                1      1  58.0         Сомони  Сегодня 21:56  330000
# 1                1     14  68.0         92 мкр  Сегодня 21:56  340000
# 2                3      8  50.0            NaN  Сегодня 21:55  700000
# 3                3     14  84.0        112 мкр  Сегодня 21:51  700000
# 4                3      3  83.0  фабрика Ширин  Сегодня 21:48  415000
#
#                         latitude,longitude
# 0                  (38.5858337, 68.793715)
# 1         (38.52225355, 68.74991793788521)
# 2                               (nan, nan)
# 3                (38.5208346, 68.74790775)
# 4  (38.564374400000005, 68.73941921022708)
